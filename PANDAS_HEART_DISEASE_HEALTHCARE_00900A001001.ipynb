# %% [markdown]
# # LOADING LIBRARIES AND DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"https://docs.google.com/spreadsheets/d/e/2PACX-1vTRWSnA-Ad7_EfgVfYUdmux3D98KVRdcJULremWE69A4lCi94pELj8mXw6jd9vcry-oAJK_k4Dd1rTx/pub?output=csv")

# %%
df.head()
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0   1   64       1       66            160           83    160.0   1.80
# 1   2   21       1       94             98           46    296.0   6.75
# 2   3   55       1       64            160           77    270.0   1.99
# 3   4   64       1       70            120           55    270.0  13.87
# 4   5   55       1       64            112           65    300.0   1.08
#
#    troponin     class
# 0     0.012  negative
# 1     1.060  positive
# 2     0.003  negative
# 3     0.122  positive
# 4     0.003  negative

# %%
df.describe()
# Out:
#                 id          age       gender      impluse  pressurehight  \
# count  1319.000000  1319.000000  1319.000000  1319.000000    1319.000000
# mean    660.000000    56.191812     0.659591    78.336619     127.170584
# std     380.906813    13.647315     0.474027    51.630270      26.122720
# min       1.000000    14.000000     0.000000    20.000000      42.000000
# 25%     330.500000    47.000000     0.000000    64.000000     110.000000
# 50%     660.000000    58.000000     1.000000    74.000000     124.000000
# 75%     989.500000    65.000000     1.000000    85.000000     143.000000
# max    1319.000000   103.000000     1.000000  1111.000000     223.000000
#
#        pressurelow      glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean     72.269143   146.634344    15.274306     0.360942
# std      14.033924    74.923045    46.327083     1.154568
# min      38.000000    35.000000     0.321000     0.001000
# 25%      62.000000    98.000000     1.655000     0.006000
# 50%      72.000000   116.000000     2.850000     0.014000
# 75%      81.000000   169.500000     5.805000     0.085500
# max     154.000000   541.000000   300.000000    10.300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1319 non-null   int64
#  1   age            1319 non-null   int64
#  2   gender         1319 non-null   int64
#  3   impluse        1319 non-null   int64
#  4   pressurehight  1319 non-null   int64
#  5   pressurelow    1319 non-null   int64
#  6   glucose        1319 non-null   float64
#  7   kcm            1319 non-null   float64
#  8   troponin       1319 non-null   float64
#  9   class          1319 non-null   object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 103.2+ KB

# %%
df_all = df.copy()

# %% [markdown]
# # DATA SYNOPSIS

# %%
for column in df_all.columns:
  display(df_all[column].value_counts())
# Out:
# id
# 1       1
# 887     1
# 885     1
# 884     1
# 883     1
#        ..
# 440     1
# 439     1
# 438     1
# 437     1
# 1319    1
# Name: count, Length: 1319, dtype: int64
# age
# 60     106
# 70      73
# 50      68
# 63      64
# 65      62
#       ...
# 88       1
# 100      1
# 14       1
# 91       1
# 84       1
# Name: count, Length: 75, dtype: int64
# gender
# 1    870
# 0    449
# Name: count, dtype: int64
# impluse
# 60     95
# 61     57
# 70     48
# 64     47
# 82     46
#        ..
# 49      1
# 46      1
# 110     1
# 36      1
# 45      1
# Name: count, Length: 79, dtype: int64
# pressurehight
# 150    50
# 130    41
# 125    41
# 120    38
# 140    32
#        ..
# 204     1
# 78      1
# 71      1
# 70      1
# 89      1
# Name: count, Length: 116, dtype: int64
# pressurelow
# 75     69
# 68     67
# 80     57
# 70     44
# 60     43
#        ..
# 102     1
# 106     1
# 38      1
# 47      1
# 154     1
# Name: count, Length: 73, dtype: int64
# glucose
# 100.0    41
# 87.0     32
# 98.0     31
# 96.0     30
# 94.0     30
#          ..
# 338.0     1
# 282.0     1
# 354.0     1
# 153.0     1
# 331.0     1
# Name: count, Length: 244, dtype: int64
# kcm
# 300.000    19
# 1.600      11
# 2.110       9
# 1.330       9
# 1.830       9
#            ..
# 0.657       1
# 3.420       1
# 3.490       1
# 5.730       1
# 4.010       1
# Name: count, Length: 700, dtype: int64
# troponin
# 0.003    190
# 0.006     67
# 0.005     65
# 0.004     64
# 0.007     54
#         ...
# 2.340      1
# 0.697      1
# 0.853      1
# 1.060      1
# 1.770      1
# Name: count, Length: 352, dtype: int64
# class
# positive    810
# negative    509
# Name: count, dtype: int64

# %%
df_all.isna().value_counts()
# Out:
# id     age    gender  impluse  pressurehight  pressurelow  glucose  kcm    troponin  class
# False  False  False   False    False          False        False    False  False     False    1319
# Name: count, dtype: int64

# %%
df_all.isna().sum()
# Out:
# id               0
# age              0
# gender           0
# impluse          0
# pressurehight    0
# pressurelow      0
# glucose          0
# kcm              0
# troponin         0
# class            0
# dtype: int64

# %%
df_all.describe(include = "all")
# Out:
#                  id          age       gender      impluse  pressurehight  \
# count   1319.000000  1319.000000  1319.000000  1319.000000    1319.000000
# unique          NaN          NaN          NaN          NaN            NaN
# top             NaN          NaN          NaN          NaN            NaN
# freq            NaN          NaN          NaN          NaN            NaN
# mean     660.000000    56.191812     0.659591    78.336619     127.170584
# std      380.906813    13.647315     0.474027    51.630270      26.122720
# min        1.000000    14.000000     0.000000    20.000000      42.000000
# 25%      330.500000    47.000000     0.000000    64.000000     110.000000
# 50%      660.000000    58.000000     1.000000    74.000000     124.000000
# 75%      989.500000    65.000000     1.000000    85.000000     143.000000
# max     1319.000000   103.000000     1.000000  1111.000000     223.000000
#
#         pressurelow      glucose          kcm     troponin     class
# count   1319.000000  1319.000000  1319.000000  1319.000000      1319
# unique          NaN          NaN          NaN          NaN         2
# top             NaN          NaN          NaN          NaN  positive
# freq            NaN          NaN          NaN          NaN       810
# mean      72.269143   146.634344    15.274306     0.360942       NaN
# std       14.033924    74.923045    46.327083     1.154568       NaN
# min       38.000000    35.000000     0.321000     0.001000       NaN
# 25%       62.000000    98.000000     1.655000     0.006000       NaN
# 50%       72.000000   116.000000     2.850000     0.014000       NaN
# 75%       81.000000   169.500000     5.805000     0.085500       NaN
# max      154.000000   541.000000   300.000000    10.300000       NaN

# %% [markdown]
# # DATA SYNOPSIS 2

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import random
import string
import warnings
warnings.filterwarnings("ignore")
import datetime
from datetime import timedelta
import time

# %%
time1 = time.time()

# %%
df_all = df.copy()

# %%
for column in df_all.columns:
  display(df_all[column].value_counts())
# Out:
# id
# 1       1
# 887     1
# 885     1
# 884     1
# 883     1
#        ..
# 440     1
# 439     1
# 438     1
# 437     1
# 1319    1
# Name: count, Length: 1319, dtype: int64
# age
# 60     106
# 70      73
# 50      68
# 63      64
# 65      62
#       ...
# 88       1
# 100      1
# 14       1
# 91       1
# 84       1
# Name: count, Length: 75, dtype: int64
# gender
# 1    870
# 0    449
# Name: count, dtype: int64
# impluse
# 60     95
# 61     57
# 70     48
# 64     47
# 82     46
#        ..
# 49      1
# 46      1
# 110     1
# 36      1
# 45      1
# Name: count, Length: 79, dtype: int64
# pressurehight
# 150    50
# 130    41
# 125    41
# 120    38
# 140    32
#        ..
# 204     1
# 78      1
# 71      1
# 70      1
# 89      1
# Name: count, Length: 116, dtype: int64
# pressurelow
# 75     69
# 68     67
# 80     57
# 70     44
# 60     43
#        ..
# 102     1
# 106     1
# 38      1
# 47      1
# 154     1
# Name: count, Length: 73, dtype: int64
# glucose
# 100.0    41
# 87.0     32
# 98.0     31
# 96.0     30
# 94.0     30
#          ..
# 338.0     1
# 282.0     1
# 354.0     1
# 153.0     1
# 331.0     1
# Name: count, Length: 244, dtype: int64
# kcm
# 300.000    19
# 1.600      11
# 2.110       9
# 1.330       9
# 1.830       9
#            ..
# 0.657       1
# 3.420       1
# 3.490       1
# 5.730       1
# 4.010       1
# Name: count, Length: 700, dtype: int64
# troponin
# 0.003    190
# 0.006     67
# 0.005     65
# 0.004     64
# 0.007     54
#         ...
# 2.340      1
# 0.697      1
# 0.853      1
# 1.060      1
# 1.770      1
# Name: count, Length: 352, dtype: int64
# class
# positive    810
# negative    509
# Name: count, dtype: int64

# %%
# display(df_all[df_all["DAYS_EMPLOYED"]== 365243]["NAME_INCOME_TYPE"].value_counts())

# %%
df_all.describe(include = "all")
# Out:
#                  id          age       gender      impluse  pressurehight  \
# count   1319.000000  1319.000000  1319.000000  1319.000000    1319.000000
# unique          NaN          NaN          NaN          NaN            NaN
# top             NaN          NaN          NaN          NaN            NaN
# freq            NaN          NaN          NaN          NaN            NaN
# mean     660.000000    56.191812     0.659591    78.336619     127.170584
# std      380.906813    13.647315     0.474027    51.630270      26.122720
# min        1.000000    14.000000     0.000000    20.000000      42.000000
# 25%      330.500000    47.000000     0.000000    64.000000     110.000000
# 50%      660.000000    58.000000     1.000000    74.000000     124.000000
# 75%      989.500000    65.000000     1.000000    85.000000     143.000000
# max     1319.000000   103.000000     1.000000  1111.000000     223.000000
#
#         pressurelow      glucose          kcm     troponin     class
# count   1319.000000  1319.000000  1319.000000  1319.000000      1319
# unique          NaN          NaN          NaN          NaN         2
# top             NaN          NaN          NaN          NaN  positive
# freq            NaN          NaN          NaN          NaN       810
# mean      72.269143   146.634344    15.274306     0.360942       NaN
# std       14.033924    74.923045    46.327083     1.154568       NaN
# min       38.000000    35.000000     0.321000     0.001000       NaN
# 25%       62.000000    98.000000     1.655000     0.006000       NaN
# 50%       72.000000   116.000000     2.850000     0.014000       NaN
# 75%       81.000000   169.500000     5.805000     0.085500       NaN
# max      154.000000   541.000000   300.000000    10.300000       NaN

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1319 non-null   int64
#  1   age            1319 non-null   int64
#  2   gender         1319 non-null   int64
#  3   impluse        1319 non-null   int64
#  4   pressurehight  1319 non-null   int64
#  5   pressurelow    1319 non-null   int64
#  6   glucose        1319 non-null   float64
#  7   kcm            1319 non-null   float64
#  8   troponin       1319 non-null   float64
#  9   class          1319 non-null   object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 103.2+ KB

# %%
# df_all.corr()

# %% [markdown]
# #DATA CLEANING

# %%
#STEPS
#check missing values
#handling missing values
#cleaning wrong data
#check duplicate values
#drop unneccesary columns

# %%
# checking missing values
df_all.isna()
# Out:
#          id    age  gender  impluse  pressurehight  pressurelow  glucose  \
# 0     False  False   False    False          False        False    False
# 1     False  False   False    False          False        False    False
# 2     False  False   False    False          False        False    False
# 3     False  False   False    False          False        False    False
# 4     False  False   False    False          False        False    False
# ...     ...    ...     ...      ...            ...          ...      ...
# 1314  False  False   False    False          False        False    False
# 1315  False  False   False    False          False        False    False
# 1316  False  False   False    False          False        False    False
# 1317  False  False   False    False          False        False    False
# 1318  False  False   False    False          False        False    False
#
#         kcm  troponin  class
# 0     False     False  False
# 1     False     False  False
# 2     False     False  False
# 3     False     False  False
# 4     False     False  False
# ...     ...       ...    ...
# 1314  False     False  False
# 1315  False     False  False
# 1316  False     False  False
# 1317  False     False  False
# 1318  False     False  False
#
# [1319 rows x 10 columns]

# %%
df_all.isna().any()
# Out:
# id               False
# age              False
# gender           False
# impluse          False
# pressurehight    False
# pressurelow      False
# glucose          False
# kcm              False
# troponin         False
# class            False
# dtype: bool

# %%
df_all.isna().sum()
# Out:
# id               0
# age              0
# gender           0
# impluse          0
# pressurehight    0
# pressurelow      0
# glucose          0
# kcm              0
# troponin         0
# class            0
# dtype: int64

# %%
# #handling missing values
# #here we can see the no has missing values

# %%
#filling the missing values in the column
# no filling required

# %%
#checking again for null values
df_all.isna().any()
# Out:
# id               False
# age              False
# gender           False
# impluse          False
# pressurehight    False
# pressurelow      False
# glucose          False
# kcm              False
# troponin         False
# class            False
# dtype: bool

# %%
#in DAYS_WORKED column we can find value which is 365243
"""for x in df_all.index:
    if df_all.loc[x,"DAYS_EMPLOYED" ]== 365243:
      df_all.loc[x,"DAYS_EMPLOYED"]= 36500
df_all["DAYS_EMPLOYED"]"""
#this is not not recommended as it is taking much time
#loc and iloc are useful for getting multiple items at a time
#at and iat are useful for getting single value at a time
# Out:
# 'for x in df_all.index:\n    if df_all.loc[x,"DAYS_EMPLOYED" ]== 365243:\n      df_all.loc[x,"DAYS_EMPLOYED"]= 36500\ndf_all["DAYS_EMPLOYED"]'

# %%
#cleaning wrong data
#in DAYS_WORKED column we can find value which is 365243
"""for x in df_all.index:
    if df_all.at[x,"DAYS_EMPLOYED" ]== 365243:
      df_all.at[x,"DAYS_EMPLOYED"]= 36500
df_all["DAYS_EMPLOYED"]"""
# Out:
# 'for x in df_all.index:\n    if df_all.at[x,"DAYS_EMPLOYED" ]== 365243:\n      df_all.at[x,"DAYS_EMPLOYED"]= 36500\ndf_all["DAYS_EMPLOYED"]'

# %%
# #cleaning wrong data
# #in DAYS_WORKED column we can find value which is 365243
# df_all.loc[df_all['DAYS_EMPLOYED']== 365243,'DAYS_EMPLOYED']= 36500

# %%
#checking for duplicated columns
df_all.duplicated().sum()
# Out:
# 0

# %%
# df.corr()

# %%
# #removing the unneccesary columns
# #as per correlation we find FLAG_MOBIL is not correlated to any column

# %%
df_all
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 10 columns]

# %% [markdown]
# #FEATURE ENGINEERING

# %%
#steps
#creating temporal variables
#categorical variables : remove rare labels
#standardise the value of variables to the same range

# %%
#creating temporal variables

# %%
df_all
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 10 columns]

# %%
df_all
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 10 columns]

# %%
df_all.head(5)
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0   1   64       1       66            160           83    160.0   1.80
# 1   2   21       1       94             98           46    296.0   6.75
# 2   3   55       1       64            160           77    270.0   1.99
# 3   4   64       1       70            120           55    270.0  13.87
# 4   5   55       1       64            112           65    300.0   1.08
#
#    troponin     class
# 0     0.012  negative
# 1     1.060  positive
# 2     0.003  negative
# 3     0.122  positive
# 4     0.003  negative

# %%
with pd.option_context('display.max_columns', None,
                      #  "display.max_Rows" , None,
                       'display.precision', 3,
                       ): # u can also insert 'display.max_rows', None
  display(df_all)
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 10 columns]

# %%
df_all['class'].value_counts().keys()
# Out:
# Index(['positive', 'negative'], dtype='object', name='class')

# %%
df_all["class"].dtype
# Out:
# dtype('O')

# %%
def solve(state):
  health_risk = ""
  if state == "positive":
    health_risk = 1 #risky
  else:
    health_risk = 0 # not risky
  return health_risk

# %%
df_all["health_risk"] = df_all["class"].apply(solve)

# %%
df_all["health_risk"].value_counts()
# Out:
# health_risk
# 1    810
# 0    509
# Name: count, dtype: int64

# %%
df_all = df_all.drop("class", axis =1)

# %%
df_all
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin  health_risk
# 0        0.012            0
# 1        1.060            1
# 2        0.003            0
# 3        0.122            1
# 4        0.003            0
# ...        ...          ...
# 1314     0.006            0
# 1315     0.172            1
# 1316     4.250            1
# 1317     0.359            1
# 1318     1.770            1
#
# [1319 rows x 10 columns]

# %% [markdown]
# # DATA VISUALISATION

# %%
df_all.corr()
# Out:
#                      id       age    gender   impluse  pressurehight  \
# id             1.000000 -0.002895 -0.017317  0.013501      -0.029452
# age           -0.002895  1.000000 -0.092874 -0.023440       0.017441
# gender        -0.017317 -0.092874  1.000000 -0.026781       0.011065
# impluse        0.013501 -0.023440 -0.026781  1.000000       0.010882
# pressurehight -0.029452  0.017441  0.011065  0.010882       1.000000
# pressurelow   -0.003345  0.002614 -0.009370  0.108353       0.586166
# glucose       -0.007854 -0.004193  0.006668 -0.019584       0.020807
# kcm           -0.012357  0.018419  0.017527 -0.013001      -0.016396
# troponin       0.016165  0.088800  0.065793  0.011180       0.043729
# health_risk    0.024112  0.238097  0.094432  0.006920      -0.020825
#
#                pressurelow   glucose       kcm  troponin  health_risk
# id               -0.003345 -0.007854 -0.012357  0.016165     0.024112
# age               0.002614 -0.004193  0.018419  0.088800     0.238097
# gender           -0.009370  0.006668  0.017527  0.065793     0.094432
# impluse           0.108353 -0.019584 -0.013001  0.011180     0.006920
# pressurehight     0.586166  0.020807 -0.016396  0.043729    -0.020825
# pressurelow       1.000000 -0.025614 -0.023403  0.043360    -0.009659
# glucose          -0.025614  1.000000  0.045757  0.021069    -0.033059
# kcm              -0.023403  0.045757  1.000000 -0.016008     0.217720
# troponin          0.043360  0.021069 -0.016008  1.000000     0.229376
# health_risk      -0.009659 -0.033059  0.217720  0.229376     1.000000

# %%
plt.figure(figsize = (30,8))
sns.heatmap(df_all.corr(),annot = True, cmap = "RdBu") #cmap = "RdYlGn")
# Out:
# <Axes: >

# %%
dfcopy = df_all.copy()
for feature in df_all.columns:
  if feature != "health_risk":
    plt.scatter(dfcopy[feature],dfcopy["health_risk"])
    plt.xlabel(feature)
    plt.ylabel("health_risk")
    plt.show()

# %%
# #requires more ram
# sns.pairplot(df_all["CNT_CHILDREN	AMT_INCOME_TOTAL	AGE	NO_OF_YEARS_WORKED	FLAG_WORK_PHONE	FLAG_PHONE	FLAG_EMAIL	CNT_FAM_MEMBERS	MONTHS_BALANCE	MALE_GENDER	OWN_CAR	OWN_LAND	Credit".split()[:4]])

# %%
sns.pairplot(df_all)

# %% [markdown]
# # FEATURE SCALING

# %%
# let's make all data in one scale,for that we have to first change the categorical data to numerical data .
df_all.head(10)
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose     kcm  \
# 0   1   64       1       66            160           83    160.0    1.80
# 1   2   21       1       94             98           46    296.0    6.75
# 2   3   55       1       64            160           77    270.0    1.99
# 3   4   64       1       70            120           55    270.0   13.87
# 4   5   55       1       64            112           65    300.0    1.08
# 5   6   58       0       61            112           58     87.0    1.83
# 6   7   32       0       40            179           68    102.0    0.71
# 7   8   63       1       60            214           82     87.0  300.00
# 8   9   44       0       60            154           81    135.0    2.35
# 9  10   67       1       61            160           95    100.0    2.84
#
#    troponin  health_risk
# 0     0.012            0
# 1     1.060            1
# 2     0.003            0
# 3     0.122            1
# 4     0.003            0
# 5     0.004            0
# 6     0.003            0
# 7     2.370            1
# 8     0.004            0
# 9     0.011            0

# %%
dfforbot1 = df_all.drop("health_risk", axis =1).copy()

# %%
dfforbot1.value_counts()
# Out:
# id    age  gender  impluse  pressurehight  pressurelow  glucose  kcm    troponin
# 1     64   1       66       160            83           160.0    1.80   0.012       1
# 887   35   1       70       117            76           111.0    2.16   0.003       1
# 885   60   0       65       129            75           132.0    28.41  0.054       1
# 884   56   1       76       150            100          103.0    2.36   0.019       1
# 883   60   1       72       113            64           161.0    2.93   0.014       1
#                                                                                    ..
# 440   45   1       84       107            55           235.0    1.61   0.044       1
# 439   60   1       70       126            75           87.0     4.11   0.013       1
# 438   65   1       65       137            75           87.0     1.60   0.085       1
# 437   42   1       75       138            67           107.0    2.22   0.003       1
# 1319  51   1       94       157            79           134.0    50.89  1.770       1
# Name: count, Length: 1319, dtype: int64

# %%
#creating a copy for not modifying the data in original data frame
df_all1 = df_all.copy()
df_all.head(1)
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose  kcm  \
# 0   1   64       1       66            160           83    160.0  1.8
#
#    troponin  health_risk
# 0     0.012            0

# %%
# dfall1 =df_all1.drop("class",axis =1)
# dfall1

# %%
df_all1.shape
# Out:
# (1319, 10)

# %%
# df_all1.drop(["MALE_GENDER"],axis = 1 , inplace =True)
# df_all1 = df_all1.drop_duplicates()
# # df_all1[df_all1["NO_OF_YEARS_WORKED"]==-100]=-100
# df_all1.info()

# %%
"""We can see that our all data in float or in int data types.Now we ready to apply FeatureScaling on our data."""
# Out:
# 'We can see that our all data in float or in int data types.Now we ready to apply FeatureScaling on our data.'

# %%
x =df_all1.drop("health_risk",axis =1)
y = df_all1.loc[:,"health_risk"]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1319 non-null   int64
#  1   age            1319 non-null   int64
#  2   gender         1319 non-null   int64
#  3   impluse        1319 non-null   int64
#  4   pressurehight  1319 non-null   int64
#  5   pressurelow    1319 non-null   int64
#  6   glucose        1319 non-null   float64
#  7   kcm            1319 non-null   float64
#  8   troponin       1319 non-null   float64
# dtypes: float64(3), int64(6)
# memory usage: 92.9 KB

# %%
feature_scale = [feature for feature in df_all1.columns if feature != "health_risk"]
#importing libraries
from sklearn.preprocessing import MinMaxScaler
scaler =MinMaxScaler()
scaler.fit(x)
# Out:
# MinMaxScaler()

# %%
(scaler.transform(x))
# Out:
# array([[0.00000000e+00, 5.61797753e-01, 1.00000000e+00, ...,
#         2.47035573e-01, 4.93528075e-03, 1.06806486e-03],
#        [7.58725341e-04, 7.86516854e-02, 1.00000000e+00, ...,
#         5.15810277e-01, 2.14529547e-02, 1.02825517e-01],
#        [1.51745068e-03, 4.60674157e-01, 1.00000000e+00, ...,
#         4.64426877e-01, 5.56929248e-03, 1.94193611e-04],
#        ...,
#        [9.98482549e-01, 3.48314607e-01, 1.00000000e+00, ...,
#         1.20553360e-01, 3.06661461e-03, 4.12564327e-01],
#        [9.99241275e-01, 4.49438202e-01, 1.00000000e+00, ...,
#         8.06324111e-01, 1.82828960e-02, 3.47606564e-02],
#        [1.00000000e+00, 4.15730337e-01, 1.00000000e+00, ...,
#         1.95652174e-01, 1.68743889e-01, 1.71764249e-01]])

# %%
df_all1 = pd.concat([y.reset_index(drop = True),pd.DataFrame(scaler.transform(x),columns=feature_scale)],axis =1)
df_all1.head(5)
# Out:
#    health_risk        id       age  gender   impluse  pressurehight  \
# 0            0  0.000000  0.561798     1.0  0.042163       0.651934
# 1            1  0.000759  0.078652     1.0  0.067828       0.309392
# 2            0  0.001517  0.460674     1.0  0.040330       0.651934
# 3            1  0.002276  0.561798     1.0  0.045830       0.430939
# 4            0  0.003035  0.460674     1.0  0.040330       0.386740
#
#    pressurelow   glucose       kcm  troponin
# 0     0.387931  0.247036  0.004935  0.001068
# 1     0.068966  0.515810  0.021453  0.102826
# 2     0.336207  0.464427  0.005569  0.000194
# 3     0.146552  0.464427  0.045212  0.011749
# 4     0.232759  0.523715  0.002533  0.000194

# %%
df_all1["health_risk"].value_counts()
# Out:
# health_risk
# 1    810
# 0    509
# Name: count, dtype: int64

# %%
""" from the above output,we conclude that data is imbalanced.so, we have to do either under sampling or over sampling.we are going to do over sampling bcz in under sampling .we will lost our almost data."""
# Out:
# ' from the above output,we conclude that data is imbalanced.so, we have to do either under sampling or over sampling.we are going to do over sampling bcz in under sampling .we will lost our almost data.'

# %% [markdown]
# # DEALING WITH UNBALANCED DATA SET

# %%
from imblearn.combine import SMOTETomek

# %%
smtk = SMOTETomek(random_state=12)

# %%
df_all1.shape
# Out:
# (1319, 10)

# %%
y = y.astype(int)
x_resamp , y_resamp = smtk.fit_resample(x,y)

# %%
x_resamp.shape,y_resamp.shape
# Out:
# ((1432, 9), (1432,))

# %%
print(f"original data set value distribution : {list(y.value_counts())}")
print(f"resampled data set value distribution : {list(y_resamp.value_counts())}")
# Out:
# original data set value distribution : [810, 509]
# resampled data set value distribution : [716, 716]

# %%
#x_resamp.groupby(["MONTHS_BALANCE","ID"]).min().nsmallest(10,columns ="CNT_CHILDREN	AMT_INCOME_TOTAL	NAME_INCOME_TYPE	NAME_EDUCATION_TYPE	NAME_FAMILY_STATUS	NAME_HOUSING_TYPE	AGE	NO_OF_YEARS_WORKED	FLAG_WORK_PHONE	FLAG_PHONE	FLAG_EMAIL	CNT_FAM_MEMBERS	STATUS".split())

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x_resamp1 = x_resamp
feature_scale1 = feature_scale

# %%
mms = MinMaxScaler()
mms.fit(x_resamp1)
# Out:
# MinMaxScaler()

# %%
x_scaled_resamp = mms.transform(x_resamp1)

# %%
df_all1scaled = pd.concat([pd.DataFrame(x_scaled_resamp,columns = feature_scale1),y_resamp],axis =1)

# %%
DF1111 = df_all[df_all1scaled["health_risk"]==1 ]
DF1111
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose  \
# 1        2   21       1       94             98           46    296.0
# 3        4   64       1       70            120           55    270.0
# 7        8   63       1       60            214           82     87.0
# 12      13   64       1       60            199           99     92.0
# 15      16   61       1       81            118           66    134.0
# ...    ...  ...     ...      ...            ...          ...      ...
# 1129  1130   75       1       89            100           50    114.0
# 1130  1131   57       1       78            101           54    115.0
# 1133  1134   65       0       80            129           89     85.0
# 1134  1135   70       1       76            136           82    233.0
# 1135  1136   78       0       73            108           61     95.0
#
#           kcm  troponin  health_risk
# 1       6.750     1.060            1
# 3      13.870     0.122            1
# 7     300.000     2.370            1
# 12      3.430     5.370            1
# 15      1.490     0.017            1
# ...       ...       ...          ...
# 1129    0.681     0.088            1
# 1130    0.826     0.014            0
# 1133    2.790     0.004            0
# 1134    2.560     2.160            1
# 1135   10.420     0.011            1
#
# [716 rows x 10 columns]

# %% [markdown]
# # MODEL DEPLOYMENT

# %%
from sklearn.model_selection import train_test_split

# %%
#pd.concat([x_resamp,y_resamp],axis = 1)[pd.concat([x_resamp,y_resamp],axis = 1)["Credit"] == 1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled_resamp,y_resamp,train_size = 0.8,random_state = 567)

# %%
x_train.shape,y_train.shape
# Out:
# ((1145, 9), (1145,))

# %%
#importing libraries
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score

# %%
modellist = [LinearRegression,DecisionTreeClassifier,GaussianNB,KNeighborsClassifier,RandomForestClassifier]

# %%
accuracylist = []
i=0
for model in modellist:
  model = model()
  model.fit(x_train,y_train)
  y_pred =model.predict(x_test)
  print("one iteration completed")
  ConfusionMatrixDisplay.from_predictions(y_test ,y_pred.astype(int))
  acc = accuracy_score(y_test,y_pred.astype(int))
  accuracylist.append(acc)
  i+=1
# Out:
# one iteration completed
# one iteration completed
# one iteration completed
# one iteration completed
# one iteration completed

# %%
"""accuracylist = []
def model_test(x_train,y_train,model):
  model = model()
  model.fit(x_train,y_train)
  y_pred =model.predict(x_test)
  ConfusionMatrixDisplay.from_predictions(y_test ,y_pred)
  acc = accuracy_score(y_test,y_pred)
  accuracylist.append(acc)
  return (y_pred)

ypredl = [model_test(x_train,y_train,i) for i in modellist ]
ypredl"""
# Out:
# 'accuracylist = []\ndef model_test(x_train,y_train,model):\n  model = model()\n  model.fit(x_train,y_train)\n  y_pred =model.predict(x_test)\n  ConfusionMatrixDisplay.from_predictions(y_test ,y_pred)\n  acc = accuracy_score(y_test,y_pred)\n  accuracylist.append(acc)\n  return (y_pred)\n\nypredl = [model_test(x_train,y_train,i) for i in modellist ]\nypredl'

# %%
display(modellist)
accuracylist
# Out:
# [sklearn.linear_model._base.LinearRegression,
#  sklearn.tree._classes.DecisionTreeClassifier,
#  sklearn.naive_bayes.GaussianNB,
#  sklearn.neighbors._classification.KNeighborsClassifier,
#  sklearn.ensemble._forest.RandomForestClassifier]
# [0.47735191637630664,
#  0.9825783972125436,
#  0.7212543554006968,
#  0.7003484320557491,
#  0.9895470383275261]

# %%
maxac = max(accuracylist)
acindex = accuracylist.index(maxac)
modelforpred = modellist[acindex]
modelforpred
# Out:
# sklearn.ensemble._forest.RandomForestClassifier

# %% [markdown]
# # CHATBOT NORMAL

# %%
#steps
#separating multifeature data and numerical data
#getting input for multifeature data
#getting numerical data
#arranging the input data as per the database

# %%
dataforbot = dfforbot1
dataforbot.head(5)
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0   1   64       1       66            160           83    160.0   1.80
# 1   2   21       1       94             98           46    296.0   6.75
# 2   3   55       1       64            160           77    270.0   1.99
# 3   4   64       1       70            120           55    270.0  13.87
# 4   5   55       1       64            112           65    300.0   1.08
#
#    troponin
# 0     0.012
# 1     1.060
# 2     0.003
# 3     0.122
# 4     0.003

# %%
#inputlist = "ID	CODE_GENDER	FLAG_OWN_CAR	FLAG_OWN_REALTY	CNT_CHILDREN	AMT_INCOME_TOTAL	NAME_INCOME_TYPE	NAME_EDUCATION_TYPE	NAME_FAMILY_STATUS	NAME_HOUSING_TYPE	DAYS_BIRTH	DAYS_EMPLOYED	FLAG_WORK_PHONE	FLAG_PHONE	FLAG_EMAIL	OCCUPATION_TYPE	CNT_FAM_MEMBERS	MONTHS_BALANCE".split()
inputlist  = list(dataforbot.columns)
inputlist
# Out:
# ['id',
#  'age',
#  'gender',
#  'impluse',
#  'pressurehight',
#  'pressurelow',
#  'glucose',
#  'kcm',
#  'troponin']

# %%
dataforbot.describe(include = "all")
# Out:
#                 id          age       gender      impluse  pressurehight  \
# count  1319.000000  1319.000000  1319.000000  1319.000000    1319.000000
# mean    660.000000    56.191812     0.659591    78.336619     127.170584
# std     380.906813    13.647315     0.474027    51.630270      26.122720
# min       1.000000    14.000000     0.000000    20.000000      42.000000
# 25%     330.500000    47.000000     0.000000    64.000000     110.000000
# 50%     660.000000    58.000000     1.000000    74.000000     124.000000
# 75%     989.500000    65.000000     1.000000    85.000000     143.000000
# max    1319.000000   103.000000     1.000000  1111.000000     223.000000
#
#        pressurelow      glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean     72.269143   146.634344    15.274306     0.360942
# std      14.033924    74.923045    46.327083     1.154568
# min      38.000000    35.000000     0.321000     0.001000
# 25%      62.000000    98.000000     1.655000     0.006000
# 50%      72.000000   116.000000     2.850000     0.014000
# 75%      81.000000   169.500000     5.805000     0.085500
# max     154.000000   541.000000   300.000000    10.300000

# %%
numdatalist = dataforbot.describe().loc["std",:][dataforbot.describe().loc["std",:] >0.5]
numdatalist = numdatalist.keys() #it takes only if the std is greater than 0.5
numdatalist
# Out:
# Index(['id', 'age', 'impluse', 'pressurehight', 'pressurelow', 'glucose',
#        'kcm', 'troponin'],
#       dtype='object')

# %%
#numdatalist = ["ID","AMT_INCOME_TOTAL","CNT_CHILDREN","DAYS_BIRTH","AGE","DAYS_EMPLOYED", "NO_OF_YEARS_WORKED","CNT_FAM_MEMBERS","MONTHS_BALANCE"]

# %%
"""inpdetlist = [[list(dataforbot[i].value_counts().keys()) , list(dataforbot[i].value_counts())] for i in inputlist if i not in numdatalist]
inpdetlist"""
# Out:
# 'inpdetlist = [[list(dataforbot[i].value_counts().keys()) , list(dataforbot[i].value_counts())] for i in inputlist if i not in numdatalist]\ninpdetlist'

# %%
#working for non num data
nonnumlist = [column for column in inputlist if column not in numdatalist]
# indetlist1 = [list(enumerate(dataforbot[column].unique(),1)) for column in nonnumlist]
indetlist1 = [list(enumerate(dataforbot[column].value_counts().keys(),1)) for column in nonnumlist]
display(nonnumlist)
indetlist1
# Out:
# ['gender']
# [[(1, 1), (2, 0)]]

# %%
#non mumerical data
def funtionnonnuminp(ind,col):
  i = 1
  while i !=0:
    try :
      print(f"Enter your {ind}  :  NOTE: IN FLAG IF 0 AND 1 ARE GIVEN, 0 MEANS NO AND 1 MEANS YES")
      input1 = int(input(f"SELECT THE NUMBER FROM THE LIST{col}"))
      if input1>len(col) or input1<1:
        raise ValueError("enter correct number")
      inpnonnumdata.append(input1)
      i=0
    except ValueError:
      print("enter correct number from list")

# %%
num = len(nonnumlist)
inpnonnumdata = []
for j in range(num):
  nameofcol = nonnumlist[j]   #0
  valcountsofcol = indetlist1[j]#0
  funtionnonnuminp(nameofcol,valcountsofcol)

inpnonnumdata
# Out:
# Enter your gender  :  NOTE: IN FLAG IF 0 AND 1 ARE GIVEN, 0 MEANS NO AND 1 MEANS YES
# SELECT THE NUMBER FROM THE LIST[(1, 1), (2, 0)]1
# [1]

# %%
datainput1 = []
for i in range(len(inpnonnumdata)):
  datainput1.append((nonnumlist[i],indetlist1[i][inpnonnumdata[i]-1][1]))
print("entered details are : ")
datainput1
# Out:
# entered details are :
# [('gender', 1)]

# %%
#dealing with numerical inputs
#for arranging in order of the columns in data given
a = dataforbot
numcol = [col for col in a.columns if col in numdatalist]
numcol
# Out:
# ['id',
#  'age',
#  'impluse',
#  'pressurehight',
#  'pressurelow',
#  'glucose',
#  'kcm',
#  'troponin']

# %%
#getting the border values of the data for bot columns
minmaxlist = []
for col in numcol:
  if dataforbot[col].max() >0:
    minmaxlist.append(dataforbot[col].max())
  else:
    minmaxlist.append(dataforbot[col].min())
minmaxlist
# Out:
# [1319, 103, 1111, 223, 154, 541.0, 300.0, 10.3]

# %%
#getting numerical data
def funtionnuminp(ind,col):
  i = 1
  while i !=0:
    try :
      print(f"Enter your {ind}  : ")
      input1 = int(input(f"SELECT ONLY NUMBER FROM 0 to {col} : "))
      if col >0:
        if input1>col or input1<0:
          raise ValueError("enter correct number")
      elif col <0:
        if input1 <col or input1>0:
          raise ValueError("enter correct number")
      inpnumdata.append(input1)
      i=0
    except ValueError:
      print("enter correct number within range specified")

# %%
inpnumdata = []
for j in range(len(numcol)):
  nameofcolumn = numcol[j]
  bordervalue = minmaxlist[j]
  funtionnuminp(nameofcolumn, bordervalue)
inpnumdata
# Out:
# Enter your id  :
# SELECT ONLY NUMBER FROM 0 to 1319 : 12
# Enter your age  :
# SELECT ONLY NUMBER FROM 0 to 103 : 27
# Enter your impluse  :
# SELECT ONLY NUMBER FROM 0 to 1111 : 546
# Enter your pressurehight  :
# SELECT ONLY NUMBER FROM 0 to 223 : 140
# Enter your pressurelow  :
# SELECT ONLY NUMBER FROM 0 to 154 : 89
# Enter your glucose  :
# SELECT ONLY NUMBER FROM 0 to 541.0 : 130
# Enter your kcm  :
# SELECT ONLY NUMBER FROM 0 to 300.0 : 45
# Enter your troponin  :
# SELECT ONLY NUMBER FROM 0 to 10.3 : 6
# [12, 27, 546, 140, 89, 130, 45, 6]

# %%
datainput2 = list(zip(numcol,inpnumdata))
datainput2
# Out:
# [('id', 12),
#  ('age', 27),
#  ('impluse', 546),
#  ('pressurehight', 140),
#  ('pressurelow', 89),
#  ('glucose', 130),
#  ('kcm', 45),
#  ('troponin', 6)]

# %%
#getting num variables that are initiated for the data
inpnonnumdata+ inpnumdata
# Out:
# [1, 12, 27, 546, 140, 89, 130, 45, 6]

# %%
dataforinptomodel = datainput1 + datainput2
dataforinptomodel
# Out:
# [('gender', 1),
#  ('id', 12),
#  ('age', 27),
#  ('impluse', 546),
#  ('pressurehight', 140),
#  ('pressurelow', 89),
#  ('glucose', 130),
#  ('kcm', 45),
#  ('troponin', 6)]

# %%
display(inpnonnumdata)
display(dfforbot1.head())
# dfforbot1["OWN_CAR"].value_counts()
# Out:
# [1]
#    id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0   1   64       1       66            160           83    160.0   1.80
# 1   2   21       1       94             98           46    296.0   6.75
# 2   3   55       1       64            160           77    270.0   1.99
# 3   4   64       1       70            120           55    270.0  13.87
# 4   5   55       1       64            112           65    300.0   1.08
#
#    troponin
# 0     0.012
# 1     1.060
# 2     0.003
# 3     0.122
# 4     0.003

# %%
xforinp = pd.DataFrame(dataforinptomodel,columns = ["inputname","inputvalue"]).transpose()
display(xforinp)
inpnonnumdata
# Out:
#                  0   1    2        3              4            5        6  \
# inputname   gender  id  age  impluse  pressurehight  pressurelow  glucose
# inputvalue       1  12   27      546            140           89      130
#
#               7         8
# inputname   kcm  troponin
# inputvalue   45         6
# [1]

# %%
#scaling data into numbers
xforinp1 = xforinp.copy()
klist = list(xforinp1.loc["inputvalue",:])
xforinp2 =[]
for i in range(len(klist)) :
  if type(klist[i])==str or type(klist[i])==object:
    xforinp2.append(inpnonnumdata[i]) #if its string get the option selected by the user
  else:
    xforinp2.append(klist[i]) #if it not of str append the same element

# %%
#unordered list of values valinp1   #the index for both unordered list depict the same value
#unordered list of columns colval1
#ordered list of columns  dfcolformodel
#ordered list of values  dfvaluesformodel
#display(list(zip(*dataforinptomodel)))

# %%
##ARRANGING AS PER DATABASE
print((xforinp2))
colval1,valueinp1 = zip(*dataforinptomodel)# column name , value of the varibale
print(colval1,valueinp1,sep = "\n\n *")
dfcolformodel =[col for col in  df_all.columns if col in colval1] #getting column names as per the database
print(dfcolformodel) #dataframe column for inputing to model
dfvaluesformodel = [] #dataframe value for inputing to model
for col in dfcolformodel:
  i =colval1.index(col)  #column name
  dfvaluesformodel.append(xforinp2[i] )
print(dfvaluesformodel)
# Out:
# [1, 12, 27, 546, 140, 89, 130, 45, 6]
# ('gender', 'id', 'age', 'impluse', 'pressurehight', 'pressurelow', 'glucose', 'kcm', 'troponin')
#
#  *(1, 12, 27, 546, 140, 89, 130, 45, 6)
# ['id', 'age', 'gender', 'impluse', 'pressurehight', 'pressurelow', 'glucose', 'kcm', 'troponin']
# [12, 27, 1, 546, 140, 89, 130, 45, 6]

# %%
#APPENDING VALUES TO THE INPUT DATABASE
xforinp1.loc["inputname",:] = dfcolformodel #test input column name for the model
xforinp1.loc['inputvalue',:] = dfvaluesformodel#test user input value for model
display(xforinp1)
xforinp3 =pd.concat([(xforinp1.loc["inputvalue",:]),xforinp1.loc["inputvalue",:]],axis =1,ignore_index = True) #getting the values user input data and doubling it by concatinating  columns based
xforinp3 =xforinp3.transpose()
xforinp3
# Out:
#              0    1       2        3              4            5        6  \
# inputname   id  age  gender  impluse  pressurehight  pressurelow  glucose
# inputvalue  12   27       1      546            140           89      130
#
#               7         8
# inputname   kcm  troponin
# inputvalue   45         6
#     0   1  2    3    4   5    6   7  8
# 0  12  27  1  546  140  89  130  45  6
# 1  12  27  1  546  140  89  130  45  6

# %%
# mMs = MinMaxScaler()
# mMs.fit(xforinp3.iloc[0,:])
# xforinp3_scaled = mMs.transform(xforinp3)
# pd.DataFrame(xforinp3_scaled)

# %% [markdown]
# # FINAL OUTPUT

# %%
modelp =modelforpred()
modelp.fit(x_scaled_resamp,y_resamp)
y_pred1 = modelp.predict(xforinp3)
y_pred1[0]
# Out:
# 1

# %%
riskfactor = []
for i in y_pred1:
  if i ==1:
    riskfactor.append("risky")
  else:
    riskfactor.append("not risky")  #output for the banker
riskfactor[0]
# Out:
# 'risky'

# %%
# riskfactor = []
# for i in y_pred1:
#   if i ==1:
#     riskfactor.append("try again after few months, your loan is rejected")
#   else:
#     riskfactor.append("the loan is approved for further process")  #output for the user
# riskfactor[0]

# %%
riskfactor = []
for i in y_pred1 :
  if i == 1:
    riskfactor.append("please consult doctor immediately as your health is in risk")
  else:
    riskfactor.append("please eat more fruits to maintain the same good health")
riskfactor[0]
# Out:
# 'please consult doctor immediately as your health is in risk'

# %%
time2 = time.time()
tottime = time2 - time1
tottime
# Out:
# 533.4144072532654

# %%
import colab
list(colab.__dir__())

# %%
colab.__cached__

# %%
colab.__builtins__
